# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarshmishra2k2/Desideratum-Of-Data-Visualisation/blob/main/Ploting%20Static%20Composition%20Of%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ploting Static Composition Of Data

# %%
#Here I Imported The Python Library 
import matplotlib.pyplot as plt
import urllib.request as url
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from matplotlib.pyplot import style      
plt.style.use(["dark_background"])      

sns.set(color_codes=1)

# %%
Penguin=sns.load_dataset("penguins")    
Penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
url01="https://data.covid19india.org/states_daily.json"

# %%
url.urlretrieve(url01,"Data02.json")
# Out:
# ('Data02.json', <http.client.HTTPMessage at 0x7f476d8c0bd0>)

# %%
# !ls -lh
# Out:
# total 1.1M
# -rw-r--r-- 1 root root 1.1M Oct 18 14:08 Data02.json
# drwxr-xr-x 1 root root 4.0K Oct 14 19:05 sample_data

# %%
import json

# %%
with open ("Data02.json") as D01: 
    Data=json.load(D01)            
Data
# Out:
# {'states_daily': [{'an': '0',
#    'ap': '1',
#    'ar': '0',
#    'as': '0',
#    'br': '0',
#    'ch': '0',
#    'ct': '0',
#    'date': '14-Mar-20',
#    'dateymd': '2020-03-14',
#    'dd': '0',
#    'dl': '7',
#    'dn': '0',
#    'ga': '0',
#    'gj': '0',
#    'hp': '0',
#    'hr': '14',
#    'jh': '0',
#    'jk': '2',
#    'ka': '6',
#    'kl': '19',
#    'la': '0',
#    'ld': '0',
#    'mh': '14',
#    'ml': '0',
#    'mn': '0',
#    'mp': '0',
#    'mz': '0',
#    'nl': '0',
#    'or': '0',
#    'pb': '1',
#    'py': '0',
#    'rj': '3',
#    'sk': '0',
#    'status': 'Confirmed',
#    'tg': '1',
#    'tn': '1',
#    'tr': '0',
#    'tt': '81',
#    'un': '0',
#    'up': '12',
#    'ut': '0',
#    'wb': '0'},
#   {'an': '0',
#    'ap': '0',
#    'ar': '0',
#    'as': '0',
#    'br': '0',
#    'ch': '0',
#    'ct': '0',
#    'date': '14-Mar-20',
#    'dateymd': '2020-03-14',
#    'dd': '0',
#    'dl': '1',
#    'dn': '0',
#    'ga': '0',
#    'gj': '0',
#    'hp': '0',
# ...

# %%
Data=Data['states_daily']

# %%
da=pd.read_json('Data02.json')

# %%
Data02=pd.json_normalize(Data)

# %%
Data03= Data02.tail(3)                        
Data03.drop("date",axis=1,inplace=True)        
Data03.drop("dateymd",axis=1,inplace=True)     
Data03.set_index("status",inplace=True)        
Data03=Data03.T                               
Data03=Data03.apply(pd.to_numeric)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Data03
# Out:
# status  Confirmed  Recovered  Deceased
# an              1          0         0
# ap            909       1543        13
# ar            165        249         0
# as            758       1014        10
# br             14         42         0
# ch              2          3         0
# ct             68        224         1
# dd              0          0         0
# dl             27         73         0
# dn              2          0         0
# ga             62         96         5
# gj             14         13         0
# hp            276        334         3
# hr             22         18         2
# jh             35         13         0
# jk             77        135         1
# ka           1065       1486        28
# kl          12294      18542       142
# la              4          9         0
# ld              6          6         0
# mh           4145       5811       100
# ml            352        649         8
# mn            275        546         6
# ...

# %% [markdown]
# Pie Chart

# %%
Penguin.groupby("species").count()     

#Here I Get The Data Frame But This Is Not Useful For Our Objective
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
Penguin.groupby("species")["species"].count()
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# Name: species, dtype: int64

# %%
Pie01=Penguin.groupby("species")["species"].count()

# %%
plt.pie(Pie01)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f476b0039d0>,
# ...
#  [Text(0.19980052901159365, 1.0817022458175296, ''),
#   Text(-1.0642320588877476, -0.2782267507547502, ''),
#   Text(0.4669023904498147, -0.9959930510762859, '')])

# %%
plt.pie(Pie01);

# %%
plt.pie(Pie01);                 
plt.show()

# %%
plt.pie(Pie01,labels=Pie01.index);

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f");

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f%%");       
#Here Note That 2 Percentage Is Use .First Is Use As Escape Character And Second Is For Percentage Sign

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f%%",explode=[1,0,0]);       #Here [0,n,0,n] Denoted The Index Number

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f%%",explode=[1,0,1]);

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f%%",explode=[0,1,0],startangle=90);

# %%
plt.pie(Pie01,labels=Pie01.index,autopct="%.4f%%",explode=[0,1,0],startangle=90,shadow=1);

# %%
plt.pie(np.random.randint(14,1412,41),autopct="%.4f%%",shadow=1);       

#Here If You See It Is Difficult To Convey The Data

# %% [markdown]
# Donut Chart

# %%
plt.pie(np.random.randint(14,1412,41),wedgeprops=dict(width=0.2));

# %%
ColorMap01=plt.get_cmap("gist_ncar")    
MyColors01=ColorMap01( np.arange(41))

# %%
plt.pie(np.random.randint(14,1412,41),wedgeprops=dict(width=0.2),colors=MyColors01);

# %%
ColorMap02=plt.get_cmap("Dark2")   
MyColors02=ColorMap02( np.arange(3))

# %%
Pie02=Penguin.groupby("island")["island"].count()

# %%
plt.pie(Pie02,labels=Pie02.index,autopct="%.4f%%",wedgeprops=dict(width=0.3),colors=MyColors02);

# %%
Pie03=pd.crosstab(Penguin.species,Penguin.island)

# %%
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.3),colors=MyColors02);

# %%
#Here I Plotted The Two Dounut In Single Graph
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.6),colors=MyColors02);
plt.pie(Pie03.values.flatten(),autopct="%.4f%%",radius=1.4,wedgeprops=dict(width=0.6));

# %%
ColorMap03=plt.get_cmap("tab20c")   
MyColors03=ColorMap03(np.array([0,4,8]))      
MyColors04=ColorMap03(np.array([1,2,3,5,6,7,9,10,11]))

# %%
#Here I Plotted The Two Dounut In Single Graph With My Color's 
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.6),colors=MyColors03);
plt.pie(Pie03.values.flatten(),autopct="%.4f%%",radius=1.4,wedgeprops=dict(width=0.6),colors=MyColors04);

# %%
#Here I Plotted The Two Dounut In Single Graph With My Color's 
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.6),colors=MyColors03);
plt.pie(Pie03.values.flatten(),autopct="%.4f%%",radius=1.4,wedgeprops=dict(width=0.6),colors=MyColors04,labeldistance=1.5);

# %%
#Here I Plotted The Two Dounut In Single Graph With My Color's 
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.6),colors=MyColors03);
plt.pie(Pie03.values.flatten(),labels=["Biscoe","Dream","Torgersen","Biscoe","Dream","Torgersen","Biscoe","Dream","Torgersen"],autopct="%.4f%%",radius=1.4,wedgeprops=dict(width=0.6),colors=MyColors04);

# %%
#Here I Plotted The Two Dounut In Single Graph With My Color's 
plt.pie(Pie03.sum(axis=1),labels=Pie03.index,autopct="%.4f%%",radius=2,wedgeprops=dict(width=0.6),colors=MyColors03);
plt.pie(Pie03.values.flatten(),labels=["Biscoe","Dream","Torgersen","Biscoe","Dream","","Biscoe","Dream",""],autopct="%.4f%%",radius=1.4,wedgeprops=dict(width=0.6),colors=MyColors04);

# %% [markdown]
# Stacked Bar Plot

# %%
Data03.head()
# Out:
# status  Confirmed  Recovered  Deceased
# an              1          0         0
# ap            909       1543        13
# ar            165        249         0
# as            758       1014        10
# br             14         42         0

# %%
plt.bar(Data03.index,Data03.Recovered);

# %%
plt.bar(Data03.index,Data03.Deceased);       
plt.xticks(rotation=90);

# %%
#Here I Plotted The Two Bar Graph In Single Graph Paper Same Color
plt.bar(Data03.index,Data03.Confirmed);          
plt.bar(Data03.index,Data03.Recovered);         
plt.xticks(rotation=90);

# %%
#Here I Plotted The Two Bar Graph In Single Graph Paper With Different Color
plt.bar(Data03.index,Data03.Confirmed);
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed);
plt.xticks(rotation=90);

# %%
plt.bar(Data03.index,Data03.Confirmed);                                         
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed);                
plt.bar(Data03.index,Data03.Deceased,bottom=Data03.Confirmed+Data03.Recovered); 
plt.xticks(rotation=90);

# %%
fig=plt.gcf();                                                                 
fig.set_size_inches(30,9)                                                       
plt.bar(Data03.index,Data03.Confirmed);                                         
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed);                
plt.bar(Data03.index,Data03.Deceased,bottom=Data03.Confirmed+Data03.Recovered);
plt.xticks(rotation=90);

# %%
fig=plt.gcf();
fig.set_size_inches(30,9)                                                      
plt.bar(Data03.index,Data03.Confirmed,color="Orange");                                      
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed,color="Blue");                
plt.bar(Data03.index,Data03.Deceased,bottom=Data03.Confirmed+Data03.Recovered,color="Green"); 
plt.xticks(rotation=90);

# %%
enumerate?

# %%
# Here The Added The Sum Values Of All Graph
fig=plt.gcf();                                                                  
fig.set_size_inches(30,9)                                                      
plt.bar(Data03.index,Data03.Confirmed,color="Orange");                                       
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed,color="Blue");                 
plt.bar(Data03.index,Data03.Deceased,bottom=Data03.Confirmed+Data03.Recovered,color="Green"); 
plt.xticks(rotation=90);                                                        

for U,values in enumerate(Data03.index):                                       
    y=Data03.loc[values].sum()+100                                                  
    x=U
    plt.text(x,y,str(y),ha="center");

# %% [markdown]
# Relative Stacked Bar Plots

# %%
Data03.head()
# Out:
# status  Confirmed  Recovered  Deceased
# an              1          0         0
# ap            909       1543        13
# ar            165        249         0
# as            758       1014        10
# br             14         42         0

# %%
Data03["Total"]=Data03.sum(axis=True)    
Data03
# Out:
# status  Confirmed  Recovered  Deceased  Total
# an              1          0         0      1
# ap            909       1543        13   2465
# ar            165        249         0    414
# as            758       1014        10   1782
# br             14         42         0     56
# ch              2          3         0      5
# ct             68        224         1    293
# dd              0          0         0      0
# dl             27         73         0    100
# dn              2          0         0      2
# ga             62         96         5    163
# gj             14         13         0     27
# hp            276        334         3    613
# hr             22         18         2     42
# jh             35         13         0     48
# jk             77        135         1    213
# ka           1065       1486        28   2579
# kl          12294      18542       142  30978
# la              4          9         0     13
# ...

# %%
#Here I Adding Fraction Of All Cases  
Data03['ConfirmedFraction']=Data03['Confirmed']/Data03['Total']     
Data03['RecoveredFraction']=Data03['Recovered']/Data03['Total']      
Data03['DeceasedFraction']=Data03['Deceased']/Data03['Total']         

Data03
# Out:
# status  Confirmed  Recovered  Deceased  Total  ConfirmedFraction  \
# an              1          0         0      1           1.000000
# ap            909       1543        13   2465           0.368763
# ar            165        249         0    414           0.398551
# as            758       1014        10   1782           0.425365
# br             14         42         0     56           0.250000
# ch              2          3         0      5           0.400000
# ct             68        224         1    293           0.232082
# dd              0          0         0      0                NaN
# dl             27         73         0    100           0.270000
# dn              2          0         0      2           1.000000
# ga             62         96         5    163           0.380368
# gj             14         13         0     27           0.518519
# hp            276        334         3    613           0.450245
# ...

# %%
# Here I Ploted The Fraction Of Each Section
fig=plt.gcf();                                                                 
fig.set_size_inches(30,9)                                                       
plt.bar(Data03.index,Data03.ConfirmedFraction,color="Orange");                                       
plt.bar(Data03.index,Data03.RecoveredFraction,bottom=Data03.ConfirmedFraction,color="Green");                 
plt.bar(Data03.index,Data03.DeceasedFraction,bottom=Data03.ConfirmedFraction+Data03.RecoveredFraction,color="Red"); 
plt.xticks(rotation=90);

# %%
Data03=Data03.sort_values('ConfirmedFraction',ascending=0)

# %%
# Here I Ploted The Fraction In  Dscending Order
fig=plt.gcf();                                                                  
fig.set_size_inches(30,9)                                                     
plt.bar(Data03.index,Data03.ConfirmedFraction,color="Orange");                                       
plt.bar(Data03.index,Data03.RecoveredFraction,bottom=Data03.ConfirmedFraction,color="Green");                 
plt.bar(Data03.index,Data03.DeceasedFraction,bottom=Data03.ConfirmedFraction+Data03.RecoveredFraction,color="Red"); 
plt.xticks(rotation=90);

# %%
Data03=Data03.sort_values('DeceasedFraction',ascending=1)

# %%
# Here I Ploted The Fraction In Ascending Order
fig=plt.gcf();                                                                 
fig.set_size_inches(30,9)                                                     
plt.bar(Data03.index,Data03.ConfirmedFraction,color="Orange");                                       
plt.bar(Data03.index,Data03.RecoveredFraction,bottom=Data03.ConfirmedFraction,color="Green");                 
plt.bar(Data03.index,Data03.DeceasedFraction,bottom=Data03.ConfirmedFraction+Data03.RecoveredFraction,color="Red"); 
plt.xticks(rotation=90);

# %%
# Here The Added The Sum Values Of All Graph
Data03=Data03.sort_values('Total',ascending=1)
fig=plt.gcf();                                                                  
fig.set_size_inches(30,9)                                                       
plt.bar(Data03.index,Data03.Confirmed,color="Orange");                                       
plt.bar(Data03.index,Data03.Recovered,bottom=Data03.Confirmed,color="Green");                 
plt.bar(Data03.index,Data03.Deceased,bottom=Data03.Confirmed+Data03.Recovered,color="Red"); 
plt.xticks(rotation=90);                                                      

for U,values in enumerate(Data03.index):                                         
    y=Data03.loc[values,"Total"]+100                                                  
    x=U
    plt.text(x,y,str(y),ha="center");

# %%
# Here I Added The The Horizontal Bar Graph
Data03=Data03.sort_values('Total',ascending=1)
fig=plt.gcf();                                                                  
fig.set_size_inches(30,9)                                                     
plt.barh(Data03.index,Data03.Confirmed,color="Orange");                                       
plt.barh(Data03.index,Data03.Recovered,left=Data03.Confirmed,color="Green");                 
plt.barh(Data03.index,Data03.Deceased,left=Data03.Confirmed+Data03.Recovered,color="Red"); 
plt.xticks(rotation=90);
